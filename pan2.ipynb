# %%
# UCI Machine Learning Repository
#Discover datasets around the world!
#archive.ics.uci.edu
#https://archive.ics.uci.edu/dataset/350/default+of+credit+card+clients

# %%
import pandas as pd

# %%
# Handling missing values
dat=pd.read_csv('credit.csv')

# %%
dat
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df=pd.DataFrame(dat)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df.isna()
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
#drop null values
df.dropna()
# fill null values
df.isna().sum() # Count of missing values
#df.dropna() # Drop missing rows
#df.fillna(strategy==mean()) # Fill missing with 0
# df['column_name'].fillna(df['column_name'].mean(), inplace=True)
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# Duplicates Handling
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# 29999    False
# Length: 30000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
df['LIMIT_BAL']=df['LIMIT_BAL'].astype('float')
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.dtypes
# Out:
# ID                              int64
# LIMIT_BAL                     float64
# SEX                             int64
# EDUCATION                       int64
# MARRIAGE                        int64
# AGE                             int64
# PAY_0                           int64
# PAY_2                           int64
# PAY_3                           int64
# PAY_4                           int64
# PAY_5                           int64
# PAY_6                           int64
# BILL_AMT1                       int64
# BILL_AMT2                       int64
# BILL_AMT3                       int64
# BILL_AMT4                       int64
# BILL_AMT5                       int64
# BILL_AMT6                       int64
# PAY_AMT1                        int64
# PAY_AMT2                        int64
# PAY_AMT3                        int64
# PAY_AMT4                        int64
# PAY_AMT5                        int64
# PAY_AMT6                        int64
# default payment next month      int64
# ...

# %%
df=df.rename(columns={'PAY_0 ':'SEPT_pay'})
df.dtypes
# Out:
# ID                              int64
# LIMIT_BAL                     float64
# SEX                             int64
# EDUCATION                       int64
# MARRIAGE                        int64
# AGE                             int64
# PAY_0                           int64
# PAY_2                           int64
# PAY_3                           int64
# PAY_4                           int64
# PAY_5                           int64
# PAY_6                           int64
# BILL_AMT1                       int64
# BILL_AMT2                       int64
# BILL_AMT3                       int64
# BILL_AMT4                       int64
# BILL_AMT5                       int64
# BILL_AMT6                       int64
# PAY_AMT1                        int64
# PAY_AMT2                        int64
# PAY_AMT3                        int64
# PAY_AMT4                        int64
# PAY_AMT5                        int64
# PAY_AMT6                        int64
# default payment next month      int64
# ...

# %%
df=df.rename(columns={'PAY_2':'AUG_pay','PAY_3':'JUL_pay','PAY_4':'JUN_pay'})
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'AUG_pay', 'JUL_pay', 'JUN_pay', 'PAY_5', 'PAY_6', 'BILL_AMT1',
#        'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
#        'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df=df.rename(columns={'BILL_AMT1':'SEPT_bill','BILL_AMT2':'AUG_bill','BILL_AMT3':'JUL_bill','BILL_AMT4':'JUN_bill','BILL_AMT5':'MAY_bill','BILL_AMT6':'APR_bill'})
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'AUG_pay', 'JUL_pay', 'JUN_pay', 'PAY_5', 'PAY_6', 'SEPT_bill',
#        'AUG_bill', 'JUL_bill', 'JUN_bill', 'MAY_bill', 'APR_bill', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df=df.rename(columns={'PAY_AMT1 ':'SEPT_PAYT','PAY_AMT2':'AUG_PAYT','PAY_AMT3':'JUL_PAYT','PAY_AMT4':'JUN_PAYT','PAY_AMT5':'MAY_PAYT','PAY_AMT6':'APR_PAYT'})

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'AUG_pay', 'JUL_pay', 'JUN_pay', 'PAY_5', 'PAY_6', 'SEPT_bill',
#        'AUG_bill', 'JUL_bill', 'JUN_bill', 'MAY_bill', 'APR_bill', 'PAY_AMT1',
#        'AUG_PAYT', 'JUL_PAYT', 'JUN_PAYT', 'MAY_PAYT', 'APR_PAYT',
#        'default payment next month'],
#       dtype='object')

# %%
"""
df = df.rename(columns={
 'PAY_0': 'sept_paystat',
 'PAY_2': 'aug_paystat',
 'PAY_3': 'july_paystat',
 'PAY_4': 'june_paystat',
 'PAY_5': 'may_paystat',
 'PAY_6': 'april_paystat',
 'BILL_AMT1': 'sept_bill',
 'BILL_AMT2': 'aug_bill',
 'BILL_AMT3': 'july_bill',
 'BILL_AMT4': 'june_bill',
 'BILL_AMT5': 'may_bill',
 'BILL_AMT6': 'april_bill',
 'PAY_AMT1': 'sept_payment',
 'PAY_AMT2': 'aug_payment',
 'PAY_AMT3': 'july_payment',
 'PAY_AMT4': 'june_payment',
 'PAY_AMT5': 'may_payment',
 'PAY_AMT6': 'april_payment'
})
07:59 PM
Syntax 
df.rename(columns={'old_column_name': 'new_column_name'}, inplace=True)

"""
# Out:
# "\ndf = df.rename(columns={\n 'PAY_0': 'sept_paystat',\n 'PAY_2': 'aug_paystat',\n 'PAY_3': 'july_paystat',\n 'PAY_4': 'june_paystat',\n 'PAY_5': 'may_paystat',\n 'PAY_6': 'april_paystat',\n 'BILL_AMT1': 'sept_bill',\n 'BILL_AMT2': 'aug_bill',\n 'BILL_AMT3': 'july_bill',\n 'BILL_AMT4': 'june_bill',\n 'BILL_AMT5': 'may_bill',\n 'BILL_AMT6': 'april_bill',\n 'PAY_AMT1': 'sept_payment',\n 'PAY_AMT2': 'aug_payment',\n 'PAY_AMT3': 'july_payment',\n 'PAY_AMT4': 'june_payment',\n 'PAY_AMT5': 'may_payment',\n 'PAY_AMT6': 'april_payment'\n})\n07:59 PM\nSyntax \ndf.rename(columns={'old_column_name': 'new_column_name'}, inplace=True)\n\n"

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  AUG_pay  \
# 0          1    20000.0    2          2         1   24      2        2
# 1          2   120000.0    2          2         2   26     -1        2
# 2          3    90000.0    2          2         2   34      0        0
# 3          4    50000.0    2          2         1   37      0        0
# 4          5    50000.0    1          2         1   57     -1        0
# ...      ...        ...  ...        ...       ...  ...    ...      ...
# 29995  29996   220000.0    1          3         1   39      0        0
# 29996  29997   150000.0    1          3         2   43     -1       -1
# 29997  29998    30000.0    1          2         2   37      4        3
# 29998  29999    80000.0    1          3         1   41      1       -1
# 29999  30000    50000.0    1          2         1   46      0        0
#
#        JUL_pay  JUN_pay  ...  JUN_bill  MAY_bill  APR_bill  PAY_AMT1  \
# ...

# %%
# replacing the values in the columns
df.replace({'SEX':{1:'M',2:'F'}},inplace=True) # to avoid data error or placement error inplace

# %%
df
# Out:
#           ID  LIMIT_BAL SEX  EDUCATION  MARRIAGE  AGE  PAY_0  AUG_pay  \
# 0          1    20000.0   F          2         1   24      2        2
# 1          2   120000.0   F          2         2   26     -1        2
# 2          3    90000.0   F          2         2   34      0        0
# 3          4    50000.0   F          2         1   37      0        0
# 4          5    50000.0   M          2         1   57     -1        0
# ...      ...        ...  ..        ...       ...  ...    ...      ...
# 29995  29996   220000.0   M          3         1   39      0        0
# 29996  29997   150000.0   M          3         2   43     -1       -1
# 29997  29998    30000.0   M          2         2   37      4        3
# 29998  29999    80000.0   M          3         1   41      1       -1
# 29999  30000    50000.0   M          2         1   46      0        0
#
#        JUL_pay  JUN_pay  ...  JUN_bill  MAY_bill  APR_bill  PAY_AMT1  \
# ...

# %%
df.replace({'MARRIAGE':{1:'MARRIED',2:'UNMARRIED',3:'OTHERS'}},inplace=True)
df
# Out:
#           ID  LIMIT_BAL SEX  EDUCATION   MARRIAGE  AGE  PAY_0  AUG_pay  \
# 0          1    20000.0   F          2    MARRIED   24      2        2
# 1          2   120000.0   F          2  UNMARRIED   26     -1        2
# 2          3    90000.0   F          2  UNMARRIED   34      0        0
# 3          4    50000.0   F          2    MARRIED   37      0        0
# 4          5    50000.0   M          2    MARRIED   57     -1        0
# ...      ...        ...  ..        ...        ...  ...    ...      ...
# 29995  29996   220000.0   M          3    MARRIED   39      0        0
# 29996  29997   150000.0   M          3  UNMARRIED   43     -1       -1
# 29997  29998    30000.0   M          2  UNMARRIED   37      4        3
# 29998  29999    80000.0   M          3    MARRIED   41      1       -1
# 29999  30000    50000.0   M          2    MARRIED   46      0        0
#
#        JUL_pay  JUN_pay  ...  JUN_bill  MAY_bill  APR_bill  PAY_AMT1  \
# ...

# %%
df.replace({'EDUCATION':{1:'UG',2:'PG',3:'HIGH SCHOOL',4:'OTHERS'}},inplace=True)
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION   MARRIAGE  AGE  PAY_0  AUG_pay  \
# 0          1    20000.0   F           PG    MARRIED   24      2        2
# 1          2   120000.0   F           PG  UNMARRIED   26     -1        2
# 2          3    90000.0   F           PG  UNMARRIED   34      0        0
# 3          4    50000.0   F           PG    MARRIED   37      0        0
# 4          5    50000.0   M           PG    MARRIED   57     -1        0
# ...      ...        ...  ..          ...        ...  ...    ...      ...
# 29995  29996   220000.0   M  HIGH SCHOOL    MARRIED   39      0        0
# 29996  29997   150000.0   M  HIGH SCHOOL  UNMARRIED   43     -1       -1
# 29997  29998    30000.0   M           PG  UNMARRIED   37      4        3
# 29998  29999    80000.0   M  HIGH SCHOOL    MARRIED   41      1       -1
# 29999  30000    50000.0   M           PG    MARRIED   46      0        0
#
#        JUL_pay  JUN_pay  ...  JUN_bill  MAY_bill  APR_bill  PAY_AMT1  \
# ...

# %%
df.replace({'default payment next month':{'PAID':'YES','PEND':'NO'}},inplace=True)
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION   MARRIAGE  AGE  PAY_0  AUG_pay  \
# 0          1    20000.0   F           PG    MARRIED   24      2        2
# 1          2   120000.0   F           PG  UNMARRIED   26     -1        2
# 2          3    90000.0   F           PG  UNMARRIED   34      0        0
# 3          4    50000.0   F           PG    MARRIED   37      0        0
# 4          5    50000.0   M           PG    MARRIED   57     -1        0
# ...      ...        ...  ..          ...        ...  ...    ...      ...
# 29995  29996   220000.0   M  HIGH SCHOOL    MARRIED   39      0        0
# 29996  29997   150000.0   M  HIGH SCHOOL  UNMARRIED   43     -1       -1
# 29997  29998    30000.0   M           PG  UNMARRIED   37      4        3
# 29998  29999    80000.0   M  HIGH SCHOOL    MARRIED   41      1       -1
# 29999  30000    50000.0   M           PG    MARRIED   46      0        0
#
#        JUL_pay  JUN_pay  ...  JUN_bill  MAY_bill  APR_bill  PAY_AMT1  \
# ...

# %%
df=df.rename(columns={'default payment next month':'TARGET'})
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION   MARRIAGE  AGE  PAY_0  AUG_pay  \
# 0          1    20000.0   F           PG    MARRIED   24      2        2
# 1          2   120000.0   F           PG  UNMARRIED   26     -1        2
# 2          3    90000.0   F           PG  UNMARRIED   34      0        0
# 3          4    50000.0   F           PG    MARRIED   37      0        0
# 4          5    50000.0   M           PG    MARRIED   57     -1        0
# ...      ...        ...  ..          ...        ...  ...    ...      ...
# 29995  29996   220000.0   M  HIGH SCHOOL    MARRIED   39      0        0
# 29996  29997   150000.0   M  HIGH SCHOOL  UNMARRIED   43     -1       -1
# 29997  29998    30000.0   M           PG  UNMARRIED   37      4        3
# 29998  29999    80000.0   M  HIGH SCHOOL    MARRIED   41      1       -1
# 29999  30000    50000.0   M           PG    MARRIED   46      0        0
#
#        JUL_pay  JUN_pay  ...  JUN_bill  MAY_bill  APR_bill  PAY_AMT1  \
# ...

# %%
target_value=df['TARGET'].value_counts() # values and count are obtained
target_value
# Out:
# TARGET
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
a=df['SEX'].value_counts()
a
# Out:
# SEX
# F    18112
# M    11888
# Name: count, dtype: int64

# %%
e=df['EDUCATION'].value_counts()
e
# Out:
# EDUCATION
# PG             14030
# UG             10585
# HIGH SCHOOL     4917
# 5                280
# OTHERS           123
# 6                 51
# 0                 14
# Name: count, dtype: int64

# %%
df.replace({'EDUCATION':{0:'PH.D',5:'M.PHIL',6:'B.TECH'}},inplace=True)
df
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION   MARRIAGE  AGE  PAY_0  AUG_pay  \
# 0          1    20000.0   F           PG    MARRIED   24      2        2
# 1          2   120000.0   F           PG  UNMARRIED   26     -1        2
# 2          3    90000.0   F           PG  UNMARRIED   34      0        0
# 3          4    50000.0   F           PG    MARRIED   37      0        0
# 4          5    50000.0   M           PG    MARRIED   57     -1        0
# ...      ...        ...  ..          ...        ...  ...    ...      ...
# 29995  29996   220000.0   M  HIGH SCHOOL    MARRIED   39      0        0
# 29996  29997   150000.0   M  HIGH SCHOOL  UNMARRIED   43     -1       -1
# 29997  29998    30000.0   M           PG  UNMARRIED   37      4        3
# 29998  29999    80000.0   M  HIGH SCHOOL    MARRIED   41      1       -1
# 29999  30000    50000.0   M           PG    MARRIED   46      0        0
#
#        JUL_pay  JUN_pay  ...  JUN_bill  MAY_bill  APR_bill  PAY_AMT1  \
# ...

# %%
c=df['EDUCATION'].value_counts()
c
# Out:
# EDUCATION
# PG             14030
# UG             10585
# HIGH SCHOOL     4917
# M.PHIL           280
# OTHERS           123
# B.TECH            51
# PH.D              14
# Name: count, dtype: int64

# %%
#Syntax 
#df.rename(columns={'old_column_name': 'new_column_name'}, inplace=True)
#df.replace({'SEX': {1 : 'Male', 2 : 'Female'}}, inplace=True)
#df['column_name'].unique()

# %%
# no classification and regression can be choosed
# instances 10k and above 
# features (columns name: minimum 15+)
